# %% [markdown]
# ## The Seventh Lab-assignment (08/05/2022 11:59'AM' - 08/09/2022 11:59PM, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand how to conduct Sampling and Distributions. The data used in this lab assignment will contain salary data and other statistics for basketball players from the 2014-2015 NBA season. This data was collected from the following sports analytic sites: [Basketball Reference](http://www.basketball-reference.com) and [Spotrac](http://www.spotrac.com). The dataset of this assignment can be downloaded from github: https://github.com/suthapalliuday/INFO5502-Summer2022/tree/main/datasets/lab-assignment-7
#
# First, set up the tests and imports by running the cell below.

# %%
# Install the required package
# !pip install datascience
# Out:
# Collecting datascience
#   Downloading datascience-0.17.5.tar.gz (727 kB)
#      -------------------------------------- 727.3/727.3 KB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting folium>=0.9.1
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
#      -------------------------------------- 95.0/95.0 KB 450.9 kB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\jesud\anaconda3\lib\site-packages (from datascience) (62.1.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\jesud\anaconda3\lib\site-packages (from datascience) (3.4.3)
# Requirement already satisfied: pandas in c:\users\jesud\anaconda3\lib\site-packages (from datascience) (1.3.4)
# Requirement already satisfied: scipy in c:\users\jesud\anaconda3\lib\site-packages (from datascience) (1.7.1)
# Requirement already satisfied: numpy in c:\users\jesud\anaconda3\lib\site-packages (from datascience) (1.20.3)
# Requirement already satisfied: ipython in c:\users\jesud\anaconda3\lib\site-packages (from datascience) (7.29.0)
# Requirement already satisfied: plotly in c:\users\jesud\anaconda3\lib\site-packages (from datascience) (5.7.0)
# Collecting branca
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\jesud\anaconda3\lib\site-packages (from folium>=0.9.1->datascience) (2.11.3)
# Requirement already satisfied: requests in c:\users\jesud\anaconda3\lib\site-packages (from folium>=0.9.1->datascience) (2.27.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jesud\anaconda3\lib\site-packages (from matplotlib>=3.0.0->datascience) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jesud\anaconda3\lib\site-packages (from matplotlib>=3.0.0->datascience) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jesud\anaconda3\lib\site-packages (from matplotlib>=3.0.0->datascience) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jesud\anaconda3\lib\site-packages (from matplotlib>=3.0.0->datascience) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jesud\anaconda3\lib\site-packages (from matplotlib>=3.0.0->datascience) (0.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\jesud\anaconda3\lib\site-packages (from ipython->datascience) (0.18.0)
# Requirement already satisfied: matplotlib-inline in c:\users\jesud\anaconda3\lib\site-packages (from ipython->datascience) (0.1.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\jesud\anaconda3\lib\site-packages (from ipython->datascience) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\jesud\anaconda3\lib\site-packages (from ipython->datascience) (0.7.5)
# Requirement already satisfied: decorator in c:\users\jesud\anaconda3\lib\site-packages (from ipython->datascience) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jesud\anaconda3\lib\site-packages (from ipython->datascience) (3.0.20)
# Requirement already satisfied: pygments in c:\users\jesud\anaconda3\lib\site-packages (from ipython->datascience) (2.10.0)
# Requirement already satisfied: colorama in c:\users\jesud\anaconda3\lib\site-packages (from ipython->datascience) (0.4.4)
# Requirement already satisfied: backcall in c:\users\jesud\anaconda3\lib\site-packages (from ipython->datascience) (0.2.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jesud\anaconda3\lib\site-packages (from pandas->datascience) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jesud\anaconda3\lib\site-packages (from plotly->datascience) (8.0.1)
# Requirement already satisfied: six in c:\users\jesud\anaconda3\lib\site-packages (from plotly->datascience) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jesud\anaconda3\lib\site-packages (from jedi>=0.16->ipython->datascience) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jesud\anaconda3\lib\site-packages (from jinja2>=2.9->folium>=0.9.1->datascience) (1.1.1)
# Requirement already satisfied: wcwidth in c:\users\jesud\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->datascience) (0.2.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jesud\anaconda3\lib\site-packages (from requests->folium>=0.9.1->datascience) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jesud\anaconda3\lib\site-packages (from requests->folium>=0.9.1->datascience) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jesud\anaconda3\lib\site-packages (from requests->folium>=0.9.1->datascience) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jesud\anaconda3\lib\site-packages (from requests->folium>=0.9.1->datascience) (1.26.7)
# Building wheels for collected packages: datascience
#   Building wheel for datascience (setup.py): started
#   Building wheel for datascience (setup.py): finished with status 'done'
#   Created wheel for datascience: filename=datascience-0.17.5-py3-none-any.whl size=732546 sha256=e5e8ca72c690625a93465741882b21a3c3b295b5e2e9161eb977a148c8ac9605
#   Stored in directory: c:\users\jesud\appdata\local\pip\cache\wheels\74\0a\88\e52ce8c2533663326372f4be6eba170267fb70dc6252234186
# Successfully built datascience
# Installing collected packages: branca, folium, datascience
# Successfully installed branca-0.5.0 datascience-0.17.5 folium-0.12.1.post1
# WARNING: You are using pip version 22.0.4; however, version 22.2.1 is available.
# You should consider upgrading via the 'C:\Users\jesud\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# Run this cell, but please don't change it.

# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
import pandas as pd

player_data = pd.read_csv ('https://raw.githubusercontent.com/suthapalliuday/INFO5502-Summer2022/main/datasets/lab-assignment-7/player_data.csv')
player_data.head()
# Out:
#              Name  Age Team  Games  Rebounds  Assists  Steals  Blocks  \
# 0    James Harden   25  HOU     81       459      565     154      60
# 1      Chris Paul   29  LAC     82       376      838     156      15
# 2   Stephen Curry   26  GSW     80       341      619     163      16
# 3   Anthony Davis   21  NOP     68       696      149     100     200
# 4  DeAndre Jordan   26  LAC     82      1226       61      81     183
#
#    Turnovers  Points
# 0        321    2217
# 1        190    1564
# 2        249    1900
# 3         95    1656
# 4        109     946

# %% [markdown]
# Run the cell below to load player and salary data that we will use for our sampling.

# %%
player_data = Table().read_table("https://raw.githubusercontent.com/suthapalliuday/INFO5502-Summer2022/main/datasets/lab-assignment-7/player_data.csv")
salary_data = Table().read_table("https://raw.githubusercontent.com/suthapalliuday/INFO5502-Summer2022/main/datasets/lab-assignment-7/salary_data.csv")
full_data = salary_data.join("PlayerName", player_data, "Name")

# The show method immediately displays the contents of a table. 
# This way, we can display the top of two tables using a single cell.
player_data.show(3)
salary_data.show(3)
full_data.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Age</th> <th>Team</th> <th>Games</th> <th>Rebounds</th> <th>Assists</th> <th>Steals</th> <th>Blocks</th> <th>Turnovers</th> <th>Points</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>James Harden </td> <td>25  </td> <td>HOU </td> <td>81   </td> <td>459     </td> <td>565    </td> <td>154   </td> <td>60    </td> <td>321      </td> <td>2217  </td>
#         </tr>
#         <tr>
#             <td>Chris Paul   </td> <td>29  </td> <td>LAC </td> <td>82   </td> <td>376     </td> <td>838    </td> <td>156   </td> <td>15    </td> <td>190      </td> <td>1564  </td>
#         </tr>
#         <tr>
#             <td>Stephen Curry</td> <td>26  </td> <td>GSW </td> <td>80   </td> <td>341     </td> <td>619    </td> <td>163   </td> <td>16    </td> <td>249      </td> <td>1900  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (489 rows omitted)</p>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PlayerName</th> <th>Salary</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Kobe Bryant      </td> <td>23500000</td>
#         </tr>
#         <tr>
#             <td>Amar'e Stoudemire</td> <td>23410988</td>
#         </tr>
#         <tr>
#             <td>Joe Johnson      </td> <td>23180790</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (489 rows omitted)</p>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PlayerName</th> <th>Salary</th> <th>Age</th> <th>Team</th> <th>Games</th> <th>Rebounds</th> <th>Assists</th> <th>Steals</th> <th>Blocks</th> <th>Turnovers</th> <th>Points</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>A.J. Price  </td> <td>62552  </td> <td>28  </td> <td>TOT </td> <td>26   </td> <td>32      </td> <td>46     </td> <td>7     </td> <td>0     </td> <td>14       </td> <td>133   </td>
#         </tr>
#         <tr>
#             <td>Aaron Brooks</td> <td>1145685</td> <td>30  </td> <td>CHI </td> <td>82   </td> <td>166     </td> <td>261    </td> <td>54    </td> <td>15    </td> <td>157      </td> <td>954   </td>
#         </tr>
#         <tr>
#             <td>Aaron Gordon</td> <td>3992040</td> <td>19  </td> <td>ORL </td> <td>47   </td> <td>169     </td> <td>33     </td> <td>21    </td> <td>22    </td> <td>38       </td> <td>243   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (489 rows omitted)</p>

# %% [markdown]
# Rather than getting data on every player (as in the tables loaded above), imagine that we had gotten data on only a smaller subset of the players. For 492 players, it's not so unreasonable to expect to see all the data, but usually we aren't so lucky.
#
# If we want to make estimates about a certain numerical property of the population (known as a statistic, e.g. the mean or median), we may have to come up with these estimates based only on a smaller sample. Whether these estimates are useful or not often depends on how the sample was gathered. We have prepared some example sample datasets to see how they compare to the full NBA dataset. Later we'll ask you to create your own samples to see how they behave.

# %% [markdown]
# To save typing and increase the clarity of your code, we will package the analysis code into a few functions. This will be useful in the rest of the lab as we will repeatedly need to create histograms and collect summary statistics from that data.

# %% [markdown]
# We've defined the histograms function below, which takes a table with columns Age and Salary and draws a histogram for each one. It uses bin widths of 1 year for Age and $1,000,000 for Salary.

# %%
def histograms(t):
    ages = t.column('Age')
    salaries = t.column('Salary')/1000000
    t1 = t.drop('Salary').with_column('Salary', salaries)
    age_bins = np.arange(min(ages), max(ages) + 2, 1) 
    salary_bins = np.arange(min(salaries), max(salaries) + 1, 1)
    t1.hist('Age', bins=age_bins, unit='year')
    plt.title('Age distribution')
    t1.hist('Salary', bins=salary_bins, unit='million dollars')
    plt.title('Salary distribution') 
    
histograms(full_data)
print('Two histograms should be displayed below')
# Out:
# Two histograms should be displayed below

# %% [markdown]
# ### Question 1 (10 points)
#
# Create a function called compute_statistics that takes a table containing ages and salaries and:
#
# (1) Draws a histogram of ages
#
# (2) Draws a histogram of salaries
#
# (3) Returns a two-element array containing the average age and average salary (in that order)
#
#
# You can call the histograms function to draw the histograms!
#
# Note: More charts will be displayed when running the test cell. Please feel free to ignore the charts.

# %%
### You code here

def compute_statistics(age_and_salary_data):
    histograms(age_and_salary_data)
    age = age_and_salary_data.column("Age")
    salary = age_and_salary_data.column("Salary")
    return make_array(np.mean(age), np.mean(salary))
    

full_stats = compute_statistics(full_data)
full_stats
# Out:
# array([  2.65365854e+01,   4.26977577e+06])

# %%
print('Avg Age:',full_stats[0])
print('Avg Salary:',full_stats[1])
# Out:
# Avg Age: 26.5365853659
# Avg Salary: 4269775.76626

# %%
# TEST
stats = compute_statistics(full_data)
plt.close()
plt.close()
round(float(stats[0]), 2) == 26.54
# Out:
# True

# %%
# TEST
stats = compute_statistics(full_data)
plt.close()
plt.close()
round(float(stats[1]), 2) == 4269775.77
# Out:
# True

# %% [markdown]
# ### Question 2 (10 points) Convenience sampling
#
# One sampling methodology, which is generally a bad idea, is to choose players who are somehow convenient to sample. For example, you might choose players from one team who are near your house, since it's easier to survey them. This is called, somewhat pejoratively, convenience sampling.
#
# Suppose you survey only relatively new players with ages less than 22. (The more experienced players didn't bother to answer your surveys about their salaries.)
#
# Assign `convenience_sample` to a subset of `full_data` that contains only the rows for players under the age of 22.

# %%
### You code here:

convenience_sample = full_data.where("Age",are.below(22))
convenience_sample
# Out:
# PlayerName      | Salary  | Age  | Team | Games | Rebounds | Assists | Steals | Blocks | Turnovers | Points
# Aaron Gordon    | 3992040 | 19   | ORL  | 47    | 169      | 33      | 21     | 22     | 38        | 243
# Alex Len        | 3649920 | 21   | PHO  | 69    | 454      | 32      | 34     | 105    | 74        | 432
# Andre Drummond  | 2568360 | 21   | DET  | 82    | 1104     | 55      | 73     | 153    | 120       | 1130
# Andrew Wiggins  | 5510640 | 19   | MIN  | 82    | 374      | 170     | 86     | 50     | 177       | 1387
# Anthony Bennett | 5563920 | 21   | MIN  | 57    | 216      | 48      | 27     | 16     | 36        | 298
# Anthony Davis   | 5607240 | 21   | NOP  | 68    | 696      | 149     | 100    | 200    | 95        | 1656
# Archie Goodwin  | 1112280 | 20   | PHO  | 41    | 74       | 44      | 18     | 9      | 48        | 231
# Ben McLemore    | 3026280 | 21   | SAC  | 82    | 241      | 140     | 77     | 19     | 138       | 996
# Bradley Beal    | 4505280 | 21   | WAS  | 63    | 241      | 194     | 76     | 18     | 123       | 962
# Bruno Caboclo   | 1458360 | 19   | TOR  | 8     | 2        | 0       | 0      | 1      | 4         | 10
# ... (34 rows omitted)

# %%
# TEST
convenience_sample.num_columns == 11
# Out:
# True

# %%
# TEST
convenience_sample.num_rows == 44
# Out:
# True

# %% [markdown]
# ### Question 3 (10 points)
#
# Assign convenience_stats to an array of the average age and average salary of your convenience sample, using the compute_statistics function. Since they're computed on a sample, these are called sample averages.

# %%
convenience_stats = compute_statistics(convenience_sample)
convenience_stats
# Out:
# array([  2.03636364e+01,   2.38353382e+06])

# %%
# TEST
len(convenience_stats) == 2
# Out:
# True

# %%
# TEST 
round(float(convenience_stats[0]), 2) == 20.36
# Out:
# True

# %%
# TEST
round(float(convenience_stats[1]), 2) == 2383533.82
# Out:
# True

# %% [markdown]
# Next, we'll compare the convenience sample salaries with the full data salaries in a single histogram. To do that, we'll need to use the bin_column option of the hist method, which indicates that all columns are counts of the bins in a particular column. The following cell does not require any changes; just run it.

# %%
def compare_salaries(first, second, first_title, second_title):
    """Compare the salaries in two tables."""
    first_salary_in_millions = first.column('Salary')/1000000
    second_salary_in_millions = second.column('Salary')/1000000
    first_tbl_millions = first.drop('Salary').with_column('Salary', first_salary_in_millions)
    second_tbl_millions = second.drop('Salary').with_column('Salary', second_salary_in_millions)
    max_salary = max(np.append(first_tbl_millions.column('Salary'), second_tbl_millions.column('Salary')))
    bins = np.arange(0, max_salary+1, 1)
    first_binned = first_tbl_millions.bin('Salary', bins=bins).relabeled(1, first_title)
    second_binned = second_tbl_millions.bin('Salary', bins=bins).relabeled(1, second_title)
    first_binned.join('bin', second_binned).hist(bin_column='bin', unit='million dollars')
    plt.title('Salaries for all players and convenience sample')

compare_salaries(full_data, convenience_sample, 'All Players', 'Convenience Sample')

# %% [markdown]
# ### Question 4 (10 points)
# Does the convenience sample give us an accurate picture of the salary of the full population? Would you expect it to, in general? Before you move on, write a short answer in English below. You can refer to the statistics calculated above or perform your own analysis.

# %%
### Please write your answer here (no code required)

"""
Answer: 

No, the convenience sample does not give us an accurate picture of the salary of the full population of NBA players
 in 2014-2015. We would not expect it to, because it is biased towards players younger than 22.


"""
# Out:
# '\nAnswer: \n\nNo, the convenience sample does not give us an accurate picture of the salary of the full population of NBA players\n in 2014-2015. We would not expect it to, because it is biased towards players younger than 22.\n\n\n'

# %% [markdown]
# ### Simple random sampling
# A more justifiable approach is to sample uniformly at random from the players.  In a **simple random sample (SRS) without replacement**, we ensure that each player is selected at most once. Imagine writing down each player's name on a card, putting the cards in an box, and shuffling the box.  Then, pull out cards one by one and set them aside, stopping when the specified sample size is reached.

# %% [markdown]
# ### Producing simple random samples
# Sometimes, it’s useful to take random samples even when we have the data for the whole population. It helps us understand sampling accuracy.
#
# ### `sample`
#
# The table method `sample` produces a random sample from the table. By default, it draws at random **with replacement** from the rows of a table. It takes in the sample size as its argument and returns a **table** with only the rows that were selected.
#
# Run the cell below to see an example call to `sample()` with a sample size of 5, with replacement.

# %%
# Just run this cell

salary_data.sample(5)
# Out:
# PlayerName    | Salary
# Corey Brewer  | 4702500
# Gary Harris   | 1519200
# Joe Johnson   | 23180790
# Kyle Anderson | 1093680
# Jeremy Lin    | 14898938

# %% [markdown]
# The optional argument with_replacement=False can be passed through sample() to specify that the sample should be drawn without replacement.
#
# Run the cell below to see an example call to sample() with a sample size of 5, without replacement.

# %%
# Just run this cell

salary_data.sample(5, with_replacement=False)
# Out:
# PlayerName       | Salary
# Hassan Whiteside | 769881
# Mitch McGary     | 1400040
# JaKarr Sampson   | 507336
# Nazr Mohammed    | 1448490
# Will Bynum       | 2915908

# %% [markdown]
# ### Question 5 (10 points)
# Produce a simple random sample of size 44 from `full_data`. Run your analysis on it again.  Run the cell a few times to see how the histograms and statistics change across different samples.

# %%
my_small_srswor_data = full_data.sample(44, with_replacement=False)
my_small_stats = compute_statistics(my_small_srswor_data)
my_small_stats

print('avg age',my_small_srswor_data.column('Age').mean())
print('avg sal',my_small_srswor_data.column('Salary').mean())
# Out:
# avg age 27.1590909091
# avg sal 3476027.65909

# %%
my_small_srswor_data = full_data.sample(44)
my_small_stats = histograms(my_small_srswor_data)
my_small_stats
print('avg age',my_small_srswor_data.column('Age').mean())
print('avg sal',my_small_srswor_data.column('Salary').mean())
# Out:
# avg age 25.8409090909
# avg sal 3884444.22727

# %%
my_small_srswor_data = full_data.sample(44)
my_small_stats = histograms(my_small_srswor_data)
my_small_stats
print('avg age',my_small_srswor_data.column('Age').mean())
print('avg sal',my_small_srswor_data.column('Salary').mean())
# Out:
# avg age 27.2045454545
# avg sal 3730877.72727

# %% [markdown]
# Before you move on, write a short answer for the following questions in English:
#
# (1) How much does the average age change across samples?
#
# (2) What about average salary?

# %%
### Please write your answer here (no code required)

"""
Answer: 

The Average age doesn't change in between 25 to 27

There is much change in average salaries that it ranges in average for different runs.The plots change on each different set
samples compared to age.


"""
# Out:
# "\nAnswer: \n\nThe Average age doesn't change in between 25 to 27\n\nThere is much change in average salaries that it ranges in average for different runs.The plots change on each different set\nsamples compared to age.\n\n\n"

# %% [markdown]
# ### Question 6 (15 points) - Optional/ Additional extra credit if you loose marks on above questions
# As in the previous question, analyze several simple random samples of size 100 from `full_data`.

# %%
my_large_srswor_data = full_data.sample(100,with_replacement=False)
my_large_stats = compute_statistics(my_large_srswor_data)

compare_salaries(full_data, my_large_srswor_data, 'All Players', 'Simple Random Sample (100)')

my_large_stats
# Out:
# array([  2.60500000e+01,   4.59974011e+06])

# %% [markdown]
# Answer the following questions in English:
#
# (1) Do the histogram shapes seem to change more or less across samples of 100 than across samples of size 44?
#
# (2) Are the sample averages and histograms closer to their true values/shape for age or for salary? What did you expect to see?

# %%
### Please write your answer here (no code required)

"""
Answer: 

1. Compared to sample size 44, the histogram shapes change less across samples of size 100.
 
2. No much close between averages and values. Histograms are closer to their true shape for salary.
 Can't depend on wages into account for the entire population. 


"""
# Out:
# "\nAnswer: \n\n1. Compared to sample size 44, the histogram shapes change less across samples of size 100.\n \n2. No much close between averages and values. Histograms are closer to their true shape for salary.\n Can't depend on wages into account for the entire population. \n\n\n"
