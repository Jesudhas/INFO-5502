# %% [markdown]
# ## The fifth Lab-assignment (07/29/2022 11:59'AM' - 08/02/2022 11:59PM, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand Data Visualization, we will practice how to create visualizations for different datasets bu using different tools.

# %% [markdown]
# Question 1 (50 points). In this questions, you will design a visualization for a small data set and provide a rigorous rationale for your design choices.
#
# Every 10 years, the census bureau documents the demographic make-up of the United States, influencing everything from congressional districting to social services. This dataset contains a high-level summary of census data for two years a century apart: 1900 and 2000. The data is a CSV (comma-separated values) file that describes the U.S. population in terms of year, reported sex (1: male, 2: female), age group (binned into 5 year segments from 0-4 years old up to 90+ years old), and the total count of people per group. There are 38 data points per year, for a total of 76 data points.
#
# You can download the dataset here:
#
# Dataset: https://github.com/suthapalliuday/INFO5502-Summer2022/blob/main/datasets/lab_assignment_05_census.csv
#
# Source: https://www.ipums.org/
#
# (1)(10 points) Start by choosing a question you'd like a visualization to answer.
#
# (2)(30 points) Generate a static visualization (i.e., a single image) that you believe effectively answers that question, and use the question as the title of your graphic.
#
# (3)(10 points) Provide a short write-up (no more than 3 paragraphs) describing your design.
#
#
# While you must use the data set given, you are free to transform the data as you see fit. Such transforms may include (but are not limited to) log transformation, computing percentages or averages, grouping elements into new categories, or removing unnecessary variables or records. You are also free to incorporate external data as you see fit. Your chart image should be interpretable without recourse to your short write-up. Do not forget to include title, axis labels or legends as needed!
#
# As different visualizations can emphasize different aspects of a data set, you should document what aspects of the data you are attempting to most effectively communicate. In short, what story are you trying to tell? Just as important, also note which aspects of the data might be obscured or down-played due to your visualization design.
#
# In your write-up, you should provide a rigorous rationale for your design decisions. Document the visual encodings you used and why they are appropriate for the data and your specific question. These decisions include the choice of visualization type, size, color, scale, and other visual elements, as well as the use of sorting or other data transformations. How do these decisions facilitate effective communication?

# %%
# Your answer here (question + explanation):
#What are the population difference between 1900 and 2000 years especially for male and female?  


# Your answer here (question + explanation):

'''
Through visualization, shows differnece in the population in male and female between 1900 and 2000.


'''
# Out:
# '\nThrough visualization, shows differnece in the population in male and female between 1900 and 2000.\n\n\n'

# %%
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt 
import random
import pandas as pan
import matplotlib


df = pan.read_csv ('https://raw.githubusercontent.com/suthapalliuday/INFO5502-Summer2022/main/datasets/lab_assignment_05_census.csv')

# %%
df.head(5)
# Out:
#    Sex  Year  Age    People
# 0    1  1900    0   4619544
# 1    1  2000    0   9735380
# 2    1  1900    5   4465783
# 3    1  2000    5  10552146
# 4    1  1900   10   4057669

# %%
# Your answer here (python code + explanation):

#import os
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt 
#from matplotlib import font_manager as fm, rcParams
import random
import pandas as pan
import matplotlib


df = pan.read_csv ('https://raw.githubusercontent.com/suthapalliuday/INFO5502-Summer2022/main/datasets/lab_assignment_05_census.csv')


for i in df.index:  # replacing 1 with male and 2 with female in our dataset
  if df['Sex'][i]==1:
     df['Sex'][i]='Male'
  else:
    df['Sex'][i]='Female'

    font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }

sns.set(rc={'figure.figsize':(25,10)}) # settign the output size of the scatterplot
plt.ticklabel_format(style='plain', axis='y') # To print the complete number on y axis instead of e^7
ax = sns.scatterplot(x="Age", y="People", data=df, hue = 'Sex', size = 'Year') # this plots our graph

plt.title("Differnece in the population in male and female between 1900 and 2000", fontdict=font)
#sns.set_title('Differnece in the population in male and female between 1900 and 2000: {}'.format(ax),fontproperties = prop,   fontsize = 14)
plt.ylabel("Number of People") # renaming Y lable
# Out:
# Text(0, 0.5, 'Number of People')

# %% [raw]
# # Your answer here (interpretation of the results):
#
# I have imported libraries such as pandas, numpy, matplotlib, random and seaborn. Here scatterplot has giving me the opportunity to put all the variables in to one graph. To see the available data, we can draw more information. I have used age on x axis, population on the y axis, hue is the sex of the people and size of the plots represents the year. In our above graph,blue represents male and orange represents female. Small dot represents year 1900, big dot represents 2000.
#
# From the output of the plot, we can see that there is a huge spike in the over all population, but difference between male and female population in those specific years is very less. So, to look into the difference in the population of male and female separately, I plotted two more graphs below for years 1900 and 2000.

# %%
year1900 =df[df['Year'] == 1900] # contains data of year 1900
year2000=df[df['Year'] == 2000]  # contains data of year 2000

fig, axes = plt.subplots(1,2, sharex=True, figsize=(20,15)) # setting the axes to plot two graphs side by side
sns.barplot(ax=axes[0],x="Age", y="People", hue="Sex", data=year1900 )
axes[0].set_title('contains data of year 1900')
sns.barplot(ax=axes[1],x="Age", y="People", hue="Sex", data=year2000)
axes[1].set_title('contains data of year 2000')

sns
# Out:
# <module 'seaborn' from 'C:\\Users\\jesud\\anaconda3\\lib\\site-packages\\seaborn\\__init__.py'>

# %% [raw]
# From above graphs we can see that, in 1900, except for the ages 15 and 20, male population gradually high in all other age groups than Female.
# However, in the 2000, till the age of 30, male population was high. Above 30 years of age, female population is high.
#
# In above age of 65 categories, the differnece is drastic.Looking in to the stats of 2000, we can say females are living long life.
